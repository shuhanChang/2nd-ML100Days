# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y:實際值
        - yp:預測值
    Return
        - mse:MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 200.755
# The Mean absolute error is 11.015

# %%
作業一
1. 你選的這組資料為何重要
心臟病一直都是比較難預測發作時間和預後效果的疾病，也是一個複雜的疾病，發作後存活的機率也很難掌握，故選擇此資料。

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
選擇Cleveland database裡面的ML資料數據，是一個研究心臟相關疾病的資料庫 

3. 蒐集而來的資料型態為何
資料型態分為量化和非量化
量化行數據為age、trestbps、chol、resting blood pressure、serum cholestoral in mg/dl、resting electrocardiographic results
maximum heart rate achieved、number of major vessels (0-3)
非量化：chest pain type、fasting blood sugar>120 mg/dl、sex、exercise induced angina、target

4. 這組資料想解決的問題如何評估
利用多項式迴歸評估預測心血管疾病的發生

作業二
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
如何定義提升業績，例如：每日營利、客戶滿意度
提升業績的方式，例如：給予司機獎勵制度、客戶優惠、宣傳方式
假設獎勵制度、客戶滿意度、客戶優惠、宣傳方式和業績有相關性
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
司機的每日收盈額、每個時段的載客率、客戶滿意度量表、目前公司給予的獎勵制度、客戶優惠方案和宣傳方式。
資料蒐集方式為司機回報和公司內部統計資料。

3. 蒐集而來的資料型態為何
可量化的數字型態和不可量化的文字型態

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
利用每日的收盈額、載客率作相關性，並做其相關性評估，定義每季業績
將獎勵制度、客戶滿意度、客戶優惠與收盈額作相關性評估。
